# %% [markdown]
# pre-processing

# %%
import pandas as pd

df = pd.read_csv("/workspaces/projectsummer/project csv.csv", header = None)
df.head(4)
# Out:
#            0           1           2           3           4           5   \
# 0         NaN  2024-09-30  2024-06-30  2024-03-31  2023-12-31  2023-09-30
# 1         报告期         三季报          中报         一季报          年报         三季报
# 2        报表类型        合并报表        合并报表        合并报表        合并报表        合并报表
# 3        营业收入   7,198,300   4,680,100   2,130,100   9,677,300   7,160,600
# 4          产品   7,198,300   4,680,100   2,130,100   9,677,300   7,160,600
#
#            6           7           8           9   ...          31  \
# 0  2023-06-30  2023-03-31  2022-12-31  2022-09-30  ...  2017-03-31
# 1          中报         一季报          年报         三季报  ...         一季报
# 2        合并报表        合并报表        合并报表        合并报表  ...        合并报表
# 3   4,825,600   2,332,900   8,146,200   5,714,400  ...     269,627
# 4   4,825,600   2,332,900   8,146,200   5,714,400  ...     269,627
#
#            32          33          34          35          36          37  \
# 0  2016-12-31  2016-09-30  2016-06-30  2016-03-31  2015-12-31  2015-09-30
# 1          年报         三季报          中报         一季报          年报         三季报
# 2        合并报表        合并报表        合并报表        合并报表        合并报表        合并报表
# 3     700,013     471,550     241,707     114,705     404,603     283,165
# 4     700,013     471,550     241,707     114,705     404,603     283,165
#
#            38          39          40
# 0  2015-06-30  2015-03-31  2014-12-31
# 1          中报         一季报          年报
# 2        合并报表        合并报表        合并报表
# 3     189,486      93,988     319,836
# 4     189,486      93,988     319,836
#
# [5 rows x 41 columns]

# %%
df.raw(4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_6995/3875813009.py in ?()
# ----> 1 df.raw(4)
#
# ~/.local/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'raw'

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                          0           1           2           3           4   \
# 0                       NaN  2024-09-30  2024-06-30  2024-03-31  2023-12-31
# 1                       报告期         三季报          中报         一季报          年报
# 2                      报表类型        合并报表        合并报表        合并报表        合并报表
# 3                      营业收入   7,198,300   4,680,100   2,130,100   9,677,300
# 4                        产品   7,198,300   4,680,100   2,130,100   9,677,300
# ..                      ...         ...         ...         ...         ...
# 61                     其他地区         NaN         NaN         NaN         NaN
# 62              2014年之前地区分类         NaN         NaN         NaN         NaN
# 63                      NaN         NaN         NaN         NaN         NaN
# 64                      NaN         NaN         NaN         NaN         NaN
# 65                      NaN         NaN         NaN         NaN         NaN
#
#             5           6           7           8           9   ...  \
# 0   2023-09-30  2023-06-30  2023-03-31  2022-12-31  2022-09-30  ...
# 1          三季报          中报         一季报          年报         三季报  ...
# 2         合并报表        合并报表        合并报表        合并报表        合并报表  ...
# 3    7,160,600   4,825,600   2,332,900   8,146,200   5,714,400  ...
# 4    7,160,600   4,825,600   2,332,900   8,146,200   5,714,400  ...
# ..         ...         ...         ...         ...         ...  ...
# 61         NaN         NaN         NaN         NaN         NaN  ...
# 62         NaN         NaN         NaN         NaN         NaN  ...
# 63         NaN         NaN         NaN         NaN         NaN  ...
# 64         NaN         NaN         NaN         NaN         NaN  ...
# 65         NaN         NaN         NaN         NaN         NaN  ...
#
#             31          32          33          34          35          36  \
# 0   2017-03-31  2016-12-31  2016-09-30  2016-06-30  2016-03-31  2015-12-31
# 1          一季报          年报         三季报          中报         一季报          年报
# 2         合并报表        合并报表        合并报表        合并报表        合并报表        合并报表
# 3      269,627     700,013     471,550     241,707     114,705     404,603
# 4      269,627     700,013     471,550     241,707     114,705     404,603
# ..         ...         ...         ...         ...         ...         ...
# 61         NaN         NaN         NaN         NaN         NaN         NaN
# 62         NaN         NaN         NaN         NaN         NaN         NaN
# 63         NaN         NaN         NaN         NaN         NaN         NaN
# 64         NaN         NaN         NaN         NaN         NaN         NaN
# 65         NaN         NaN         NaN         NaN         NaN         NaN
#
#             37          38          39          40
# 0   2015-09-30  2015-06-30  2015-03-31  2014-12-31
# 1          三季报          中报         一季报          年报
# 2         合并报表        合并报表        合并报表        合并报表
# 3      283,165     189,486      93,988     319,836
# 4      283,165     189,486      93,988     319,836
# ..         ...         ...         ...         ...
# 61         NaN         NaN         NaN         NaN
# 62         NaN         NaN         NaN         NaN
# 63         NaN         NaN         NaN         NaN
# 64         NaN         NaN         NaN         NaN
# 65         NaN         NaN         NaN         NaN
#
# [66 rows x 41 columns]>

# %%
rows = df.iloc[[3, 18]]

print(rows)
# Out:
#           0          1          2          3          4          5   \
# 3       营业收入  7,198,300  4,680,100  2,130,100  9,677,300  7,160,600
# 18      营业成本  5,871,200  3,852,700  1,760,500  7,911,300  5,838,400
#
#            6          7          8          9   ...       31       32  \
# 3   4,825,600  2,332,900  8,146,200  5,714,400  ...  269,627  700,013
# 18  3,921,200  1,881,800  6,060,900  4,206,800  ...  202,832  540,088
#
#          33       34       35       36       37       38      39       40
# 3   471,550  241,707  114,705  404,603  283,165  189,486  93,988  319,836
# 18  355,152  188,982   89,458  312,252  212,671  142,141  67,981  231,669
#
# [2 rows x 41 columns]

# %%
# !pip install statsmodels
# Out:
# Collecting statsmodels
#   Downloading statsmodels-0.14.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.2 kB)
# Requirement already satisfied: numpy<3,>=1.22.3 in /home/codespace/.local/lib/python3.12/site-packages (from statsmodels) (2.2.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /home/codespace/.local/lib/python3.12/site-packages (from statsmodels) (1.15.2)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /home/codespace/.local/lib/python3.12/site-packages (from statsmodels) (2.2.3)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Downloading patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: packaging>=21.3 in /home/codespace/.local/lib/python3.12/site-packages (from statsmodels) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.1)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Downloading statsmodels-0.14.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 48.3 MB/s eta 0:00:00:00:01
# Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-1.0.1 statsmodels-0.14.4
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import statsmodels.api as sm
# 取第4行和第19行
Y_raw = df.iloc[3][1:]
X_raw = df.iloc[18][1:]

# replace ',' to ''
Y = Y_raw.str.replace(',', '').astype(float)
X = X_raw.str.replace(',', '').astype(float)

# delet NaN
mask = (~X.isna()) & (~Y.isna())
X = X[mask]
Y = Y[mask]

#  add constant
X = sm.add_constant(X)

# model
model = sm.OLS(Y, X).fit()

# Output regression coefficient and R^2
coefficients = model.params
intercept = coefficients.loc['const']      
slope = coefficients.loc[X.columns[1]]      

r_squared = model.rsquared

print(f"regression equation：Y = {intercept:.4f} + {slope:.4f} * X")
print(f"R² = {r_squared:.4f}")
# Out:
# regression equation：Y = 9734.2464 + 1.2615 * X
# R² = 0.9960
